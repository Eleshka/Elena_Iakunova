# %%
# !pip install python-docx
# !pip install docx2txt
import docx
import docx2txt as d2t
text = open('/content/Podcast_materials.txt','r')
#text = d2t.process('/content/Podcast_materials.docx')
#print (text)
word_counts = {}
for word in text:
  if word in word_counts:
    word_counts[word]+=1
  else:
    word_counts[word]=1
print(word_counts)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: docx2txt in /usr/local/lib/python3.10/dist-packages (0.8)
# {'Congratulations to Nezhinsky\n': 1, 'The argument for a colleague to go to a corporate party is that if he goes, but our corporate party will be a little better and more fun.\n': 1, '\n': 6, 'Question at work\n': 1, 'It is necessary to supply the flavor liquid to the flavor manufacturer.\n': 1, 'At first, the manufacturer of the fragrance said that he could use a liquid, a few weeks later it turned out that a gel was used.\n': 1, 'The manufacturer of the fragrance offers to send a sample, they will analyze the aroma and make a gel with such a smell.\n': 1, 'Colleagues, hello!\n': 1, 'To the question "How do you like this statement?" I can answer the following: I absolutely do not believe that the Chinese supplier of car fragrance systems will be able to repeat the smell that we plan to develop with professional perfumers at the required level of quality. Most likely, instead of good perfumes, we will get an air freshener with a sharp pungent smell.\n': 1, 'In this regard, there are a number of organizational issues that I consider necessary to voice:\n': 1, '1) Fragrance supplier ? Fragrance system supplier. Our cars belong to the luxury class, and smells for cars should be developed by professionals who do not just understand what luxury is, but live in this environment themselves. It is necessary to strictly separate these 2 areas of work, they will be connected only by the technical requirements for a bottle of liquid.\n': 1, '2) The very idea of using gel has not been tested. We checked how the fluid works and how the cartridges work. The liquid is building us up, moreover, a more global idea is tied to the liquid, not tied to the car, which is now in the implementation process, because we have agreed on this with you.\n': 1, '3) Is it still possible to request / buy samples of the proposed system with gel from the supplier in order to test the quality and functionality and remove a number of issues?\n': 1, 'Colleagues, if at this stage we have a misunderstanding, I suggest we meet and discuss everything in detail once again. Otherwise, we risk getting a system / odors that are completely inconsistent in their essence with the class of the car.\n': 1}

# %% [markdown]
# # Новый раздел

# %%
# Open the file in read mode
text = open("/content/Podcast_materials.txt", "r")
  
#text = d2t.process('/content/Podcast_materials.docx')
# Create an empty dictionary
d = dict()
  
# Loop through each line of the file
for line in text:
    # Remove the leading spaces and newline character
    line = line.strip()
  
    # Convert the characters in line to
    # lowercase to avoid case mismatch
    line = line.lower()
  
    # Split the line into words
    words = line.split(" ")
                         
  
    # Iterate over each word in line
    for word in words:
        # Check if the word is already in dictionary
        if word in d:
            # Increment count of word by 1
            d[word] = d[word] + 1
        else:
            # Add the word to dictionary with count 1
            d[word] = 1
  
# Print the contents of dictionary
for key in list(d.keys()):
    print(key, ":", d[key])
# Out:
# congratulations : 1
# to : 16
# nezhinsky : 1
# the : 27
# argument : 1
# for : 3
# a : 16
# colleague : 1
# go : 1
